# %%
# Program 1
import numpy as np
arr1=np.array([[1,2],[3,4]])
arr2=np.array([[5,6],[7,8]])
print(arr1+arr2)

# %%
# Program 3
import matplotlib.pyplot as plt
years = [2017, 2018, 2019, 2020, 2021, 2022]
open_sensex=[2,3,4,5,6,7]
close_sensex=[4,5,6,7,8,12]
plt.bar(years,open_sensex)
plt.bar(years,close_sensex)
plt.show()

# %%
# Program 6
years=[2010,2011,2012,2013,2014]
sensex=[17473,20622,15535,19513,21222]
plt.plot(years,sensex)
plt.show()

# %%
# Program 7
plt.scatter(years,sensex)
plt.show()
